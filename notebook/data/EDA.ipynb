# %%
import pandas as pd # type: ignore #type:

# %%
df = pd.read_csv("gemstone.csv")
df.head(20)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0            1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1            2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2            3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3            4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4            5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# 5            6   1.02      Ideal     D     VS2   61.5   56.0  6.46  6.49
# 6            7   1.01       Good     H     SI1   63.7   60.0  6.35  6.30
# 7            8   0.50    Premium     E     SI1   61.5   62.0  5.09  5.06
# 8            9   1.21       Good     H     SI1   63.8   64.0  6.72  6.63
# 9           10   0.35      Ideal     F     VS2   60.5   57.0  4.52  4.60
# 10          11   0.32      Ideal     E     VS2   61.6   56.0  4.40  4.43
# 11          12   1.10    Premium     D     SI1   60.7   55.0  6.74  6.71
# ...

# %%
# !python --version
# Out:
# Python 3.8.20

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %%
df.shape
# Out:
# (26967, 11)

# %%
len(df)
# Out:
# 26967

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
# check for duplicate records
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
# segregate numerical and categorical columns

numerical_columns=df.columns[df.dtypes!= 'object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:", numerical_columns)
print("categorical columns:",categorical_columns)
# Out:
# Numerical columns: Index(['Unnamed: 0', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# categorical columns: Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[ "Unnamed: 0"].describe()
# Out:
# count    26967.000000
# mean     13484.000000
# std       7784.846691
# min          1.000000
# 25%       6742.500000
# 50%      13484.000000
# 75%      20225.500000
# max      26967.000000
# Name: Unnamed: 0, dtype: float64

# %%
df[categorical_columns].describe()
# Out:
#           cut  color clarity
# count   26967  26967   26967
# unique      5      7       8
# top     Ideal      G     SI1
# freq    10816   5661    6571

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    5661
# E    4917
# F    4729
# H    4102
# D    3344
# I    2771
# J    1443
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()  # This will now work on the mapped numerical values
# Out:
# clarity
# SI1     6571
# VS2     6099
# SI2     4575
# VS1     4093
# VVS2    2531
# VVS1    1839
# IF       894
# I1       365
# Name: count, dtype: int64

# %%
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt # type: ignore

plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
## categorical data
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt # type: ignore
plt.figure(figsize=(8,6))
x=0
for i in categorical_columns:
    sns.catplot(data=df,x=i,kind='count')
    print('\n')
    plt.show()
# Out:
# c:\Users\DELL\newmlproject\DiamondPricePredictions\venvt\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\DELL\newmlproject\DiamondPricePredictions\venvt\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\DELL\newmlproject\DiamondPricePredictions\venvt\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head(1)
# Out:
#    Unnamed: 0  carat    cut color clarity  depth  table     x     y     z  \
# 0           1    0.3  Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
#
#    price
# 0    499

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %%
df['depth'].describe()
# Out:
# count    26270.000000
# mean        61.745147
# std          1.412860
# min         50.800000
# 25%         61.000000
# 50%         61.800000
# 75%         62.500000
# max         73.600000
# Name: depth, dtype: float64

# %%
df['depth'].hist()
# Out:
# <Axes: >

# %%
# check the missing percentage in 'depth' because it have missing values
missing_percentage = (df['depth'].isnull().sum()/len(df))*100
print (f"missing values in 'depth':{missing_percentage:.2f}%")
# Out:
# missing values in 'depth':2.58%

# %%
# since the missing value is less than 30 percentage , no need to remove the column
#consider imputation (mean/median/mode/interpolation)

# %%
# check the depth distribution
sns.histplot(df['depth'],kde=True,bins=30)
plt.show()

# %%
# fill the depth with mean values

df['depth'].fillna(df['depth'].mean(),inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26967 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
print(df['depth'].unique())
# Out:
# [62.1        60.8        62.2        61.6        60.4        61.5
#  63.7        63.8        60.5        60.7        61.1        66.2
#  61.2        59.8        61.9        60.         62.9        62.7
#  61.7        62.4        61.4        61.74514656 64.         62.3
#  63.         59.9        62.8        61.3        62.         61.
#  63.9        62.6        62.5        61.8        58.         64.9
#  60.9        59.7        63.2        58.4        59.4        63.5
#  63.1        66.8        65.2        60.6        64.3        60.2
#  60.3        65.5        58.5        68.3        66.5        63.3
#  58.8        63.6        63.4        57.5        59.         58.7
#  59.1        64.1        64.5        64.4        60.1        57.6
#  70.6        59.2        59.3        50.8        58.9        65.4
#  58.6        59.5        56.7        67.         66.         54.6
#  59.6        64.7        66.9        64.6        64.8        58.2
# ...

# %%
## corelation
sns.heatmap(df[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
 #currently we will not execute this
## df.drop(labels=['x','y','z']axis =1)

# %%
df.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype=object)

# %%
cut_map= {"fair":1,"good":2,"very good":3,"premium":4,"ideal":5}

# %%
df['clarity'].unique()
# Out:
# array(['SI1', 'IF', 'VVS2', 'VS1', 'VVS1', 'VS2', 'SI2', 'I1'],
#       dtype=object)

# %%
clarity_map = { "I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}

# %%
df['color'].unique()
# Out:
# array(['E', 'G', 'F', 'D', 'H', 'J', 'I'], dtype=object)

# %%
color_map = { "D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
df["cut"] = df['cut'].map(cut_map)
df["clarity"] = df['clarity'].map(clarity_map)
df["color"] = df['color'].map(color_map)
